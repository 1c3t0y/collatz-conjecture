# %% [markdown]
# # Examples of the CollatzProblem Class
#
# In this notebook you will find some examples and a short documentation for the *CollatzProblem* class. The CollatzProblem class contains multiple functions aimed to analyze the 3n + 1 problem and it's characteristics such as: orbits, periods, plots, fixed points, etc.

# %% [markdown]
# ## Importing the collatz.py file
#
# The importing method of this file assumes that this notebook is inside /Collatz/Examples folder, if you are working in a different folder follow some of the examples in https://www.geeksforgeeks.org/python-import-module-from-different-directory/

# %%
# Adding collatz package to python path
import sys
sys.path.append('..')

# importing the dynamical package
from collatz.collatz import CollatzProblem

#other useful libraries
import numpy as np
import random

# %% [markdown]
# # CollatzProblem Class

# %%
random_values = range(1,30)
collatz = CollatzProblem(random_values, start = 'periods')
print(collatz.orbits)
# Out:
# [[1], [2, 1], [3, 10, 5, 16, 8, 4, 2, 1], [4, 2, 1], [5, 16, 8, 4, 2, 1], [6, 3, 10, 5, 16, 8, 4, 2, 1], [7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [8, 4, 2, 1], [9, 28, 14, 7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [10, 5, 16, 8, 4, 2, 1], [11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [12, 6, 3, 10, 5, 16, 8, 4, 2, 1], [13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [14, 7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [15, 46, 23, 70, 35, 106, 53, 160, 80, 40, 20, 10, 5, 16, 8, 4, 2, 1], [16, 8, 4, 2, 1], [17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [18, 9, 28, 14, 7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [19, 58, 29, 88, 44, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [20, 10, 5, 16, 8, 4, 2, 1], [21, 64, 32, 16, 8, 4, 2, 1], [22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1], [23, 70, 35, 106, 53, 160, 80, 40, 20, 10, 5, 16, 8, 4, 2, 1], [24, 12, 6, 3, 10, 5, 16, 8, 4, 2, 1]
# ...

# %% [markdown]
# # CollatzProblem.f(self)

# %%
collatz.f()
# Out:
# [4, 1, 10, 2, 16, 3, 22, 4, 28, 5]

# %% [markdown]
# # CollatzProblem.orbit(self, values = None, inplace = False)

# %%
collatz.orbit()
# Out:
# [[1],
#  [2, 1],
#  [3, 10, 5, 16, 8, 4, 2, 1],
#  [4, 2, 1],
#  [5, 16, 8, 4, 2, 1],
#  [6, 3, 10, 5, 16, 8, 4, 2, 1],
#  [7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1],
#  [8, 4, 2, 1],
#  [9, 28, 14, 7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1],
#  [10, 5, 16, 8, 4, 2, 1]]

# %% [markdown]
# # CollatzProblem.orbits_and_periods(self, values = None, inplace = False)

# %%
collatz.orbits_and_periods()
# Out:
# ([1, 2, 8, 3, 6, 9, 17, 4, 20, 7],
#  [[1],
#   [2, 1],
#   [3, 10, 5, 16, 8, 4, 2, 1],
#   [4, 2, 1],
#   [5, 16, 8, 4, 2, 1],
#   [6, 3, 10, 5, 16, 8, 4, 2, 1],
#   [7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1],
#   [8, 4, 2, 1],
#   [9, 28, 14, 7, 22, 11, 34, 17, 52, 26, 13, 40, 20, 10, 5, 16, 8, 4, 2, 1],
#   [10, 5, 16, 8, 4, 2, 1]])

# %%
collatz.plot_orbits()

# %%
collatz.plot_vertical_orbits()

# %%
collatz.values
# Out:
# range(1, 11)

# %%
collatz.plot_directed_orbit(collatz.values[-1])

# %%
collatz.plot_directed_orbits()
