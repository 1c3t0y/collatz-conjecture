# %%
# Adding collatz package to python path
import sys
sys.path.append('..')

# importing the dynamical package
from collatz.collatz import CollatzProblem
from collatz.functions import collatz_function_short, collatz_function
from collatz.collatz import stopping_time_ratio, stopping_time

#other useful libraries
import numpy as np
import random

import matplotlib.pyplot as plt

# %%
collatz8 = CollatzProblem(list(range(2**500 + 1, 2**500 + 35654)), start = 'periods',f = collatz_function_short)

# %%
collatz8.plot_iterations(figsize = (18,9))
# Out:
# /home/icetoy/.local/lib/python3.10/site-packages/matplotlib/ticker.py:739: RuntimeWarning: overflow encountered in double_scalars
#   if abs_min // 10 ** oom != abs_max // 10 ** oom)
# /home/icetoy/.local/lib/python3.10/site-packages/matplotlib/ticker.py:739: RuntimeWarning: invalid value encountered in double_scalars
#   if abs_min // 10 ** oom != abs_max // 10 ** oom)
# /home/icetoy/.local/lib/python3.10/site-packages/matplotlib/ticker.py:739: RuntimeWarning: divide by zero encountered in double_scalars
#   if abs_min // 10 ** oom != abs_max // 10 ** oom)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 collatz8.plot_iterations(figsize = (18,9))
#
# File ~/Documents/MAC/Tesis/collatz/Examples/../collatz/collatz.py:211, in CollatzProblem.plot_iterations(self, *args, **kwargs)
#     209 if self.periods is None:
#     210 	self.periods = self.period()
# --> 211 plot.plot_iterations(self.values, self.periods, *args, **kwargs)
#
# File ~/Documents/MAC/Tesis/collatz/Examples/../collatz/plot.py:187, in plot_iterations(initial_values, periods_list, display_mode, savefig_name, figsize, *args, **kwargs)
#     185 	plt.show()
#     186 else:
# --> 187 	plt.savefig(savefig_name)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1158, in Axis.draw(self, renderer, *args, **kwargs)
#    1155     return
#    1156 renderer.open_group(__name__, gid=self.get_gid())
# -> 1158 ticks_to_draw = self._update_ticks()
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1046, in Axis._update_ticks(self)
#    1041 """
#    1042 Update ticks (position and labels) using the current data interval of
#    1043 the axes.  Return the list of ticks that will be drawn.
#    1044 """
#    1045 major_locs = self.get_majorticklocs()
# -> 1046 major_labels = self.major.formatter.format_ticks(major_locs)
#    1047 major_ticks = self.get_major_ticks(len(major_locs))
#    1048 self.major.formatter.set_locs(major_locs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py:223, in Formatter.format_ticks(self, values)
#     221 def format_ticks(self, values):
#     222     """Return the tick labels for all the ticks at once."""
# --> 223     self.set_locs(values)
#     224     return [self(value, i) for i, value in enumerate(values)]
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py:710, in ScalarFormatter.set_locs(self, locs)
#     708 if len(self.locs) > 0:
#     709     if self._useOffset:
# --> 710         self._compute_offset()
#     711     self._set_order_of_magnitude()
#     712     self._set_format()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py:738, in ScalarFormatter._compute_offset(self)
#     733 # What is the smallest power of ten such that abs_min and abs_max are
#     734 # equal up to that precision?
#     735 # Note: Internally using oom instead of 10 ** oom avoids some numerical
#     736 # accuracy issues.
#     737 oom_max = np.ceil(math.log10(abs_max))
# --> 738 oom = 1 + next(oom for oom in itertools.count(oom_max, -1)
#     739                if abs_min // 10 ** oom != abs_max // 10 ** oom)
#     740 if (abs_max - abs_min) / 10 ** oom <= 1e-2:
#     741     # Handle the case of straddling a multiple of a large power of ten
#     742     # (relative to the span).
#     743     # What is the smallest power of ten such that abs_min and abs_max
#     744     # are no more than 1 apart at that precision?
#     745     oom = 1 + next(oom for oom in itertools.count(oom_max, -1)
#     746                    if abs_max // 10 ** oom - abs_min // 10 ** oom > 1)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/ticker.py:738, in <genexpr>(.0)
#     733 # What is the smallest power of ten such that abs_min and abs_max are
#     734 # equal up to that precision?
#     735 # Note: Internally using oom instead of 10 ** oom avoids some numerical
#     736 # accuracy issues.
#     737 oom_max = np.ceil(math.log10(abs_max))
# --> 738 oom = 1 + next(oom for oom in itertools.count(oom_max, -1)
#     739                if abs_min // 10 ** oom != abs_max // 10 ** oom)
#     740 if (abs_max - abs_min) / 10 ** oom <= 1e-2:
#     741     # Handle the case of straddling a multiple of a large power of ten
#     742     # (relative to the span).
#     743     # What is the smallest power of ten such that abs_min and abs_max
#     744     # are no more than 1 apart at that precision?
#     745     oom = 1 + next(oom for oom in itertools.count(oom_max, -1)
#     746                    if abs_max // 10 ** oom - abs_min // 10 ** oom > 1)
#
# KeyboardInterrupt:

# %% [markdown]
# # Collatz function behaivor

# %%
collatz0 = CollatzProblem(range(1,100), f = collatz_function_short)
collatz1 = CollatzProblem(range(1,1000), f = collatz_function_short)
collatz2 = CollatzProblem(range(1,10000), f = collatz_function_short)

# %%
collatz0.plot_iterations(figsize = (18,9))
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.,  80.]),
#  [Text(0, -10.0, '$\\mathdefault{−10}$'),
#   Text(0, 0.0, '$\\mathdefault{0}$'),
#   Text(0, 10.0, '$\\mathdefault{10}$'),
#   Text(0, 20.0, '$\\mathdefault{20}$'),
#   Text(0, 30.0, '$\\mathdefault{30}$'),
#   Text(0, 40.0, '$\\mathdefault{40}$'),
#   Text(0, 50.0, '$\\mathdefault{50}$'),
#   Text(0, 60.0, '$\\mathdefault{60}$'),
#   Text(0, 70.0, '$\\mathdefault{70}$'),
#   Text(0, 80.0, '$\\mathdefault{80}$')])

# %%
collatz1.plot_iterations(figsize = (18,9))

# %%
collatz2.plot_iterations(figsize = (18,9))
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# (array([-25.,   0.,  25.,  50.,  75., 100., 125., 150., 175.]),
#  [Text(0, -25.0, '$\\mathdefault{−25}$'),
#   Text(0, 0.0, '$\\mathdefault{0}$'),
#   Text(0, 25.0, '$\\mathdefault{25}$'),
#   Text(0, 50.0, '$\\mathdefault{50}$'),
#   Text(0, 75.0, '$\\mathdefault{75}$'),
#   Text(0, 100.0, '$\\mathdefault{100}$'),
#   Text(0, 125.0, '$\\mathdefault{125}$'),
#   Text(0, 150.0, '$\\mathdefault{150}$'),
#   Text(0, 175.0, '$\\mathdefault{175}$')])

# %% [markdown]
# # Stopping time

# %%
stopping_time_ratio(3, collatz_function_short)
# Out:
# 4.551196133134186

# %%
values = range(2, 100000)
stopping = [stopping_time_ratio(value, collatz_function_short) for value in values]
plt.figure(figsize = (18,9))
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.axhline(y = 6.143161, color = 'r', linestyle = '-')
plt.scatter(values, stopping)

# %%
values = range(2, 2**16)
stopping = [stopping_time(value, collatz_function_short) for value in values]
plt.figure(figsize = (18,9))
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
#plt.axhline(y = 6.143161, color = 'r', linestyle = '-')
plt.scatter(values, stopping)

# %%
collatz5 = CollatzProblem(range(1,27), f = collatz_function_short)
collatz5.plot_directed_orbits(figsize = (8,14), node_size = 1200, font_size = 15)

# %%
collatz6 = CollatzProblem(range(1,20), f = collatz_function_short)
collatz6.plot_orbits(figsize = (15,7), fontsize = (15,15))

# %%
collatz7 = CollatzProblem(range(1,100), f = collatz_function_short)
collatz7.plot_orbits(figsize = (50,25), fontsize = (40,30), legend = False)

# %%
collatz7 = CollatzProblem(range(1,10000), f = collatz_function_short)
collatz7.plot_orbits(figsize = (50,25), fontsize = (40,30), legend = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <module>
#       1 collatz7 = CollatzProblem(range(1,10000), f = collatz_function_short)
# ----> 2 collatz7.plot_orbits(figsize = (50,25), fontsize = (40,30), legend = False)
#
# File ~/Documents/MAC/Tesis/collatz/Examples/../collatz/collatz.py:149, in CollatzProblem.plot_orbits(self, function_name, display_mode, label_data, savefig_name, legend, markers, title, figsize, fontsize)
#     146 def plot_orbits(self, function_name = '$Collatz(x)$', display_mode = 'show', label_data = False, savefig_name = '', legend = True, markers = None, title ='', figsize = (8,6), fontsize = (12,9)):
#     148 	orbits_label = ["Orbit of " + "{:.0f}".format(value) for value in self.values]
# --> 149 	plot.plot_orbits(self.orbits, orbits_label,
#     150 				function_name = function_name, display_mode = display_mode,
#     151 				label_data = label_data, savefig_name = savefig_name, legend = legend,
#     152 				markers = markers, title = title, figsize = figsize, fontsize=fontsize)
#
# File ~/Documents/MAC/Tesis/collatz/Examples/../collatz/plot.py:105, in plot_orbits(orbits_list, orbits_label, function_name, display_mode, label_data, savefig_name, legend, markers, title, figsize, fontsize)
#     102 	plt.legend()
#     104 if display_mode == 'show':
# --> 105 	plt.show()
#     106 else:
#     107 	plt.savefig(savefig_name)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File /usr/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/lines.py:857, in Line2D.draw(self, renderer)
#     854     gc.restore()
#     856 renderer.close_group('line2d')
# --> 857 self.stale = False
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:297, in Artist.stale(self, val)
#     292 self._stale = val
#     294 # if the artist is animated it does not take normal part in the
#     295 # draw stack and is not expected to be drawn as part of the normal
#     296 # draw loop (when not saving) so do not propagate this change
# --> 297 if self.get_animated():
#     298     return
#     300 if val and self.stale_callback is not None:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:832, in Artist.get_animated(self)
#     829     """Return the visibility."""
#     830     return self._visible
# --> 832 def get_animated(self):
#     833     """Return whether the artist is animated."""
#     834     return self._animated
#
# KeyboardInterrupt:

# %%
[(collatz6.values[index], len(orbit)) for index, orbit in enumerate(collatz6.orbits)]
# Out:
# [(1, 1),
#  (2, 2),
#  (3, 6),
#  (4, 3),
#  (5, 5),
#  (6, 7),
#  (7, 12),
#  (8, 4),
#  (9, 14),
#  (10, 6),
#  (11, 11),
#  (12, 8),
#  (13, 8),
#  (14, 13),
#  (15, 13),
#  (16, 5),
#  (17, 10),
#  (18, 15),
#  (19, 15)]

# %%
collatz8 = CollatzProblem(range(7083, 7100), f = collatz_function_short)
collatz8.plot_iterations(figsize = (18,9))
